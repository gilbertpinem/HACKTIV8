# %% [markdown]
# ## PANDAS NICH
# Pandas adalah Library yang digunakan untuk memanipulasi table

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %% [markdown]
# Untuk read csv dari lokal
# pd.read_csv("D://Hacktiv//apalah.csv")

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head()
## Bisa diatur mau ambil berapa row
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# BISA GANTI DATA TYPE CUY

df.gameorder = df.gameorder.astype(str)
df.gameorder = df.gameorder.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int32
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
## BASIC STATISTIC

# %%
df.describe()
## by default akan mendeskripsikan yang numerikal sahaja boi
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df['gameorder']
# Out:
# 0             1
# 1             1
# 2             2
# 3             2
# 4             3
#           ...
# 126309    63155
# 126310    63156
# 126311    63156
# 126312    63157
# 126313    63157
# Name: gameorder, Length: 126314, dtype: int32

# %%
df['elo_i']
# Out:
# 0         1300.0000
# 1         1300.0000
# 2         1300.0000
# 3         1306.7233
# 4         1300.0000
#             ...
# 126309    1723.4149
# 126310    1809.9791
# 126311    1704.3949
# 126312    1700.7391
# 126313    1813.6349
# Name: elo_i, Length: 126314, dtype: float64

# %%
df['opp_fran']
# Out:
# 0            Knicks
# 1           Huskies
# 2            Knicks
# 3             Stags
# 4          Capitols
#             ...
# 126309     Warriors
# 126310    Cavaliers
# 126311     Warriors
# 126312     Warriors
# 126313    Cavaliers
# Name: opp_fran, Length: 126314, dtype: object

# %%
## BISA JUGA GINI BRAY

# %%
df.gameorder
# Out:
# 0             1
# 1             1
# 2             2
# 3             2
# 4             3
#           ...
# 126309    63155
# 126310    63156
# 126311    63156
# 126312    63157
# 126313    63157
# Name: gameorder, Length: 126314, dtype: int32

# %%
## Apabila ingin mengambil beberapa coloumn

# %%
df[['gameorder', 'game_id', 'year_id']].head(10)  ## head(10) ini cuma buat nampilin 10 data teratas coy
# Out:
#    gameorder       game_id  year_id
# 0          1  194611010TRH     1947
# 1          1  194611010TRH     1947
# 2          2  194611020CHS     1947
# 3          2  194611020CHS     1947
# 4          3  194611020DTF     1947
# 5          3  194611020DTF     1947
# 6          4  194611020PRO     1947
# 7          4  194611020PRO     1947
# 8          5  194611020STB     1947
# 9          5  194611020STB     1947

# %%
## Value counts

# %%
## Digunakan untuk melihat kumpulan data dari masing2 kolom itu seperti apa

# %%
df['year_id'].value_counts()
# Out:
# 2014    2638
# 2006    2638
# 2008    2632
# 2009    2630
# 2013    2628
#         ...
# 1959     620
# 1955     618
# 1958     618
# 1957     614
# 1948     430
# Name: year_id, Length: 69, dtype: int64

# %%
df['game_result'].value_counts(normalize = True)
## Normalize ini buat liat presentase cuy
# Out:
# L    0.5
# W    0.5
# Name: game_result, dtype: float64

# %%
## Conditional Filtering

# %%
df.head
# Out:
# <bound method NDFrame.head of         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df[df['fran_id']=='Huskies']
# Out:
#      gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 0            1  194611010TRH   NBA        0     1947   11/1/1946           1
# 10           6  194611030CLR   NBA        1     1947   11/3/1946           2
# 24          13  194611080TRH   NBA        0     1947   11/8/1946           3
# 26          14  194611090CHS   NBA        1     1947   11/9/1946           4
# 49          25  194611150TRH   NBA        0     1947  11/15/1946           5
# 50          26  194611160BOS   NBA        1     1947  11/16/1946           6
# 64          33  194611180PIT   NBA        1     1947  11/18/1946           7
# 69          35  194611190TRH   NBA        0     1947  11/19/1946           8
# 83          42  194611220TRH   NBA        0     1947  11/22/1946           9
# 91          46  194611230WSC   NBA        1     1947  11/23/1946          10
# 104         53  194611260TRH   NBA        0     1947  11/26/1946          11
# ...

# %%
df[(df['seasongame']>60) & (df['fran_id']=='Knicks')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 663           332  194704020CLR   NBA        1     1947   4/2/1947
# 670           336  194704050NYK   NBA        0     1947   4/5/1947
# 678           340  194704090NYK   NBA        0     1947   4/9/1947
# 684           343  194704120GSW   NBA        1     1947  4/12/1947
# 689           345  194704140NYK   NBA        0     1947  4/14/1947
# ...           ...           ...   ...      ...      ...        ...
# 126025      63013  201504080NYK   NBA        0     2015   4/8/2015
# 126056      63029  201504100NYK   NBA        0     2015  4/10/2015
# 126072      63037  201504110ORL   NBA        1     2015  4/11/2015
# 126094      63048  201504130ATL   NBA        1     2015  4/13/2015
# 126147      63074  201504150NYK   NBA        0     2015  4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# 663             61            1     NYK  Knicks   51  1332.1560  1316.3640
# ...

# %%
df[(df['fran_id'] == 'Cavaliers') & (df['pts'] >= 40) & (df['opp_pts'] <= 80)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 22899       11450  197101190BUF   NBA        1     1971   1/19/1971
# 29591       14796  197312050PHI   NBA        1     1974   12/5/1973
# 31746       15874  197411210CLE   NBA        0     1975  11/21/1974
# 32168       16085  197412230CLE   NBA        0     1975  12/23/1974
# 34244       17123  197512020CLE   NBA        0     1976   12/2/1975
# ...           ...           ...   ...      ...      ...         ...
# 123238      61620  201403300CLE   NBA        0     2014   3/30/2014
# 124088      62045  201411240CLE   NBA        0     2015  11/24/2014
# 125473      62737  201503030CLE   NBA        0     2015    3/3/2015
# 125534      62768  201503070CLE   NBA        0     2015    3/7/2015
# 126274      63138  201505140CHI   NBA        1     2015   5/14/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %% [markdown]
# ## LOC dan ILOC

# %% [markdown]
# *ILOC* mengakses data berdasarkan urutan indeks
# *LOC* mengakses data berdasarkan label

# %%
## Creating dataframe

# %%
## 1. Dengan LIST

# %%
list_a = [[1,2,3], [4,5,6], [7,8,9]]
pd.DataFrame(list_a)

indexkolom = pd.DataFrame(list_a, columns = ['Jakarta','Bandung','Medan'], index = ['Mobil','Motor','Becak'])
indexkolom
# Out:
#        Jakarta  Bandung  Medan
# Mobil        1        2      3
# Motor        4        5      6
# Becak        7        8      9

# %%
indexkolom.iloc[0]
# Out:
# Jakarta    1
# Bandung    2
# Medan      3
# Name: Mobil, dtype: int64

# %%
indexkolom.loc['Mobil']
# Out:
# Jakarta    1
# Bandung    2
# Medan      3
# Name: Mobil, dtype: int64

# %%
indexkolom.loc['Mobil', 'Jakarta']
# Out:
# 1

# %%
indexkolom.loc['Motor', 'Jogja'] = 4

# %%
indexkolom
# Out:
#        Jakarta  Bandung  Medan  Joga  Jogja
# Mobil        1        2      3   NaN    NaN
# Motor        4        5      6   4.0    4.0
# Becak        7        8      9   NaN    NaN

# %%
df.loc[5000:7000, 'seasongame':'game_location']
# Out:
#       seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 5000          42            0     PHW   Warriors   85  1346.3630  1345.4856
# 5001          45            0     NYK     Knicks   90  1663.3676  1664.2450
# 5002          42            0     BLB  Baltimore   79  1358.2220  1355.9099
# 5003          45            0     SYR     Sixers   94  1620.1327  1622.4448
# 5004          46            0     SYR     Sixers   98  1622.4448  1630.7344
# ...          ...          ...     ...        ...  ...        ...        ...
# 6996          49            0     PHW   Warriors   93  1599.4049  1588.2762
# 6997          47            0     STL      Hawks  105  1511.3802  1522.5089
# 6998          49            0     SYR     Sixers   90  1537.7802  1542.7595
# 6999          47            0     FTW    Pistons   85  1551.4215  1546.4421
# 7000          50            0     SYR     Sixers   98  1542.7595  1540.1091
#
# ...

# %%
## Membuat datframe dengan dictionary

# %%
details ={
    'Nama' : ['Handoko', 'Sari','Rahmat', 'Heru'],
    'Age'  : [21,23,23,21],
    'Sex'  : ['M', 'W','M','M']
}
df_dict = pd.DataFrame(details)
df_dict
# Out:
#       Nama  Age Sex
# 0  Handoko   21   M
# 1     Sari   23   W
# 2   Rahmat   23   M
# 3     Heru   21   M

# %%
## AGREGAS TABLE

# %%
df['seasongame'].sum()
# Out:
# 5498920

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# ## Mengambil SUM points dari KNICKS pada tahun 2005

# %%
df[(df['fran_id']=='Knicks') & (df['year_id']==2005)]['pts'].sum()
# Out:
# 7977

# %%
df.loc[(df['fran_id']=='Knicks') & (df['year_id']==2005), 'pts'].sum()
# Out:
# 7977

# %%
df.loc[(df['fran_id']=='Knicks') & (df['year_id']==2005), 'pts'].max()
# Out:
# 135

# %%
df.loc[(df['fran_id']=='Knicks') & (df['year_id']==2005), 'pts'].min()
# Out:
# 61

# %%
df.loc[(df['fran_id']=='Knicks') & (df['year_id']==2005), 'pts'].mean()
# Out:
# 97.28048780487805

# %%
## Menampilkan total kemenangan semua tim
df.groupby('fran_id')[['pts']].max()
# Out:
#               pts
# fran_id
# Baltimore     126
# Bombers       109
# Bucks         166
# Bulls         156
# Capitols      118
# Cavaliers     154
# Celtics       173
# Clippers      152
# Colonels      157
# Condors       156
# Denver        108
# Falcons        92
# Floridians    160
# Grizzlies     144
# Hawks         155
# Heat          141
# Hornets       133
# Huskies        93
# Ironmen        85
# Jazz          153
# Jets          110
# Kings         165
# Knicks        152
# Lakers        162
# Magic         155
# Mavericks     156
# Nets          166
# Nuggets       184
# Olympians     112
# Pacers        177
# Packers       123
# Pelicans      141
# Pistons       186
# Raptors       136
# Rebels         92
# Redskins      141
# Rockets       156
# Sails         176
# Sixers        163
# Sounds        146
# Spirits       156
# Spurs         171
# Squires       169
# Stags         115
# Stars         154
# Steamrollers  107
# Suns          173
# Thunder       154
# ...

# %%
# QUIZ 3

# %%
stags_2005 = df[(df['year_id'] == 2005) & (df['fran_id'] == 'Stags')]
rata2 = stags_2005.groupby(['game_location', 'game_result'])['pts'].mean()
rata2
# Out:
# Series([], Name: pts, dtype: float64)

# %%
dflah = df[(df['fran_id']=='Stags') & (df['year_id']==1947)].groupby(['game_location', 'game_result'])['pts'].mean()

# %%
dflah = df[(df['fran_id']=='Stags') & (df['year_id']==1947)].groupby(['game_location', 'game_result'])['pts'].mean().reset_index(name='Avg score')
print(dflah)
# Out:
#   game_location game_result  Avg score
# 0             A           L  71.352941
# 1             A           W  80.210526
# 2             H           L  66.181818
# 3             H           W  80.320000

# %% [markdown]
# ## Manipulating Columns
#
# Bisa obrak - abrik kolom nya coy

# %%
nba = df.copy()

# %%
## Tambah Kolom
nba['Difference'] = nba['pts'] - nba['opp_pts']

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH  Huskies  ...     NYK    Knicks       68  1300.0000
# 1            0     NYK   Knicks  ...     TRH   Huskies       66  1300.0000
# 2            0     CHS    Stags  ...     NYK    Knicks       47  1306.7233
# 3            0     NYK   Knicks  ...     CHS     Stags       63  1300.0000
# 4            0     DTF  Falcons  ...     WSC  Capitols       50  1300.0000
#
#    opp_elo_n game_location  game_result  forecast  notes Difference
# ...

# %%
nba['opp_pts'] = 50

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH  Huskies  ...     NYK    Knicks       50  1300.0000
# 1            0     NYK   Knicks  ...     TRH   Huskies       50  1300.0000
# 2            0     CHS    Stags  ...     NYK    Knicks       50  1306.7233
# 3            0     NYK   Knicks  ...     CHS     Stags       50  1300.0000
# 4            0     DTF  Falcons  ...     WSC  Capitols       50  1300.0000
#
#    opp_elo_n game_location  game_result  forecast  notes Difference
# ...

# %%
## UNTUk MEMINDAHKAN KOLOM
nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes',
#        'Difference'],
#       dtype='object')

# %%
nba = nba[['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
       'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts','Difference', 'elo_i',
       'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
       'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes']]

# %%
nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'Difference',
#        'Difference', 'elo_i', 'elo_n', 'win_equiv', 'opp_id', 'opp_fran',
#        'opp_pts', 'opp_elo_i', 'opp_elo_n', 'game_location', 'game_result',
#        'forecast', 'notes'],
#       dtype='object')

# %%
nba.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
# RENAME COLUMN

nba2 = nba.rename(columns={'date_game':'date', 'seasongame':'season'})

# %%
nba2
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id       date  season  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946       1
# 1               1  194611010TRH   NBA        1     1947  11/1/1946       1
# 2               2  194611020CHS   NBA        0     1947  11/2/1946       1
# 3               2  194611020CHS   NBA        1     1947  11/2/1946       2
# 4               3  194611020DTF   NBA        0     1947  11/2/1946       1
# ...           ...           ...   ...      ...      ...        ...     ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015     100
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015     102
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015     101
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015     102
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015     103
#
# ...

# %%
## DROP COLUMN COUY
nba2.drop('opp_elo_i', axis = 1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id       date  season  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946       1
# 1               1  194611010TRH   NBA        1     1947  11/1/1946       1
# 2               2  194611020CHS   NBA        0     1947  11/2/1946       1
# 3               2  194611020CHS   NBA        1     1947  11/2/1946       2
# 4               3  194611020DTF   NBA        0     1947  11/2/1946       1
# ...           ...           ...   ...      ...      ...        ...     ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015     100
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015     102
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015     101
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015     102
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015     103
#
# ...

# %%
nba2drp = nba2.drop(['gameorder', 'is_playoffs'], axis = 1)

# %%
nba2drp
# Out:
#              game_id lg_id  _iscopy  year_id       date  season team_id  \
# 0       194611010TRH   NBA        0     1947  11/1/1946       1     TRH
# 1       194611010TRH   NBA        1     1947  11/1/1946       1     NYK
# 2       194611020CHS   NBA        0     1947  11/2/1946       1     CHS
# 3       194611020CHS   NBA        1     1947  11/2/1946       2     NYK
# 4       194611020DTF   NBA        0     1947  11/2/1946       1     DTF
# ...              ...   ...      ...      ...        ...     ...     ...
# 126309  201506110CLE   NBA        0     2015  6/11/2015     100     CLE
# 126310  201506140GSW   NBA        0     2015  6/14/2015     102     GSW
# 126311  201506140GSW   NBA        1     2015  6/14/2015     101     CLE
# 126312  201506170CLE   NBA        0     2015  6/16/2015     102     CLE
# 126313  201506170CLE   NBA        1     2015  6/16/2015     103     GSW
#
#           fran_id  pts  Difference  ...  win_equiv  opp_id   opp_fran  \
# ...

# %%
nba2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date           126314 non-null  object
#  6   season         126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  Difference     126314 non-null  int64
#  12  Difference     126314 non-null  int64
#  13  elo_i          126314 non-null  float64
#  14  elo_n          126314 non-null  float64
#  15  win_equiv      126314 non-null  float64
#  16  opp_id         126314 non-null  object
# ...

# %%
nba2['date'] = pd.to_datetime(nba.date_game)

# %%
nba2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date           126314 non-null  datetime64[ns]
#  6   season         126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  Difference     126314 non-null  int64
#  12  Difference     126314 non-null  int64
#  13  elo_i          126314 non-null  float64
#  14  elo_n          126314 non-null  float64
#  15  win_equiv      126314 non-null  float64
#  16  opp_id         126314 non-null  object
# ...

# %%
nba['dategame'] = pd.to_datetime(nba.date_game)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7632\513946967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba['dategame'] = pd.to_datetime(nba.date_game)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  Difference     126314 non-null  int64
#  12  Difference     126314 non-null  int64
#  13  elo_i          126314 non-null  float64
#  14  elo_n          126314 non-null  float64
#  15  win_equiv      126314 non-null  float64
#  16  opp_id         126314 non-null  object
# ...

# %%
nba2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date           126314 non-null  object
#  6   season         126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  Difference     126314 non-null  int64
#  12  Difference     126314 non-null  int64
#  13  elo_i          126314 non-null  float64
#  14  elo_n          126314 non-null  float64
#  15  win_equiv      126314 non-null  float64
#  16  opp_id         126314 non-null  object
# ...

# %%
nba2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date           126314 non-null  datetime64[ns]
#  6   season         126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  Difference     126314 non-null  int64
#  12  Difference     126314 non-null  int64
#  13  elo_i          126314 non-null  float64
#  14  elo_n          126314 non-null  float64
#  15  win_equiv      126314 non-null  float64
#  16  opp_id         126314 non-null  object
# ...

# %%
## MENGUBAH TIPE DATA
nba2['gameorder'] = nba2['gameorder'].astype(float)

# %%
nba2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  float64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date           126314 non-null  datetime64[ns]
#  6   season         126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  Difference     126314 non-null  int64
#  12  Difference     126314 non-null  int64
#  13  elo_i          126314 non-null  float64
#  14  elo_n          126314 non-null  float64
#  15  win_equiv      126314 non-null  float64
#  16  opp_id         126314 non-null  object
# ...

# %%
## BISA UBAH UPPER LOWER BUAT STRING
nba['fran_id'].str.upper()
# Out:
# 0           HUSKIES
# 1            KNICKS
# 2             STAGS
# 3            KNICKS
# 4           FALCONS
#             ...
# 126309    CAVALIERS
# 126310     WARRIORS
# 126311    CAVALIERS
# 126312    CAVALIERS
# 126313     WARRIORS
# Name: fran_id, Length: 126314, dtype: object

# %%
nba['team_id'].str.lower()
# Out:
# 0         trh
# 1         nyk
# 2         chs
# 3         nyk
# 4         dtf
#          ...
# 126309    cle
# 126310    gsw
# 126311    cle
# 126312    cle
# 126313    gsw
# Name: team_id, Length: 126314, dtype: object

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
nba2 = nba2['fran_id'].str.upper()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7632\2333411723.py in <module>
# ----> 1 nba2 = nba2['fran_id'].str.upper()
#
# G:\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# G:\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# G:\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     387                     raise KeyError(key) from err
# ...

# %%
nba2['team_id'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7632\2348478897.py in <module>
# ----> 1 nba2 = nba2['team_id'].str.lower()
#
# G:\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# G:\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# G:\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     387                     raise KeyError(key) from err
# ...

# %%
nba2.head()
# Out:
# 0    HUSKIES
# 1     KNICKS
# 2      STAGS
# 3     KNICKS
# 4    FALCONS
# Name: fran_id, dtype: object

# %% [markdown]
# ## COMBINING DATASET

# %%
df8 = pd.DataFrame({'Fisika': [70,80,90,30], 'Matematika': [65,85,75,40], 'Biologi': [55, 45, 75, 85]},
                   index=['Andi', 'Budi', 'Caca', 'Dedi'])
df8
# Out:
#       Fisika  Matematika  Biologi
# Andi      70          65       55
# Budi      80          85       45
# Caca      90          75       75
# Dedi      30          40       85

# %%
df9 = pd.DataFrame({'Fisika': [70,80,90,30], 'Matematika': [65,85,75,40], 'Biologi': [55, 45, 75, 85]},
                   index=['Rosa', 'Ahmad', 'Tukiyem', 'Jajang'])
df9
# Out:
#          Fisika  Matematika  Biologi
# Rosa         70          65       55
# Ahmad        80          85       45
# Tukiyem      90          75       75
# Jajang       30          40       85

# %%
 pd.concat([df8,df9])
# Out:
#          Fisika  Matematika  Biologi
# Andi         70          65       55
# Budi         80          85       45
# Caca         90          75       75
# Dedi         30          40       85
# Rosa         70          65       55
# Ahmad        80          85       45
# Tukiyem      90          75       75
# Jajang       30          40       85

# %%
countries = pd.DataFrame({'population' : [10,20,30],
                         'continent' : ['europe','asia','america'],
                         }, index=['Holland','Japan','Canada'])
countries2 = pd.DataFrame({'president_gender' : ['M','F','M'],
                         'Minister' : ['Yes','No','Yes'],
                         }, index=['Holland','Japan','Canada'])

# %%
countries
# Out:
#          population continent
# Holland          10    europe
# Japan            20      asia
# Canada           30   america

# %%
countries2
# Out:
#         president_gender Minister
# Holland                M      Yes
# Japan                  F       No
# Canada                 M      Yes

# %%
pd.merge(countries,countries2,left_index=True,right_index=True)
# Out:
#          population continent president_gender Minister
# Holland          10    europe                M      Yes
# Japan            20      asia                F       No
# Canada           30   america                M      Yes
